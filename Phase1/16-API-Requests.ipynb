# %% [markdown]
# # APIs - Gathering Data Using Requests

# %% [markdown]
# ## Objectives
#
# - Send requests and receive responses over the web
# - Retrieve data from APIs using the `requests` library
# - Parse API responses

# %% [markdown]
# ## The Many Use Cases For APIs
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information you might want through their API
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? **Every API is different!** There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Types of Requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it locally
#!pip install requests

# %%
# Create a GET request, then check the type of object

r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"20623203324","type":"PushEvent","actor":{"id":92473363,"login":"Mofazzal-145","display_login":"Mofazzal-145","gravatar_id":"","url":"https://api.github.com/users/Mofazzal-145","avatar_url":"https://avatars.githubusercontent.com/u/92473363?"},"repo":{"id":467135558,"name":"Mofazzal-145/js-concepts-for-react","url":"https://api.github.com/repos/Mofazzal-145/js-concepts-for-react"},"payload":{"push_id":9287928128,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"3122261f2ee65a3cecce1aff23c75f73545ec83e","before":"df0c357f01072f0c09301e5fa408d537ea11a50d","commits":[{"sha":"3122261f2ee65a3cecce1aff23c75f73545ec83e","author":{"email":"md.mofazzalhossain145@gmail.com","name":"Mofazzal-145"},"message":"t:string, a:func, s:operator","distinct":true,"url":"https://api.github.com/repos/Mofazzal-145/js-concepts-for-react/commits/3122261f2ee65a3cecce1aff23c75f73545ec83e"}]},"public":true,"created_at":"2022-03-07T19:33:32Z"},{"id":"20623203341","type":"PushEvent","actor":{"id":60201494,"login":"nastassiagoodson","display_login":"nastassiagoodson","gravatar_id":"","url":"https://api.github.com/users/nastassiagoodson","avatar_url":"https://avatars.githubusercontent.com/u/60201494?"},"repo":{"id":465920826,"name":"nastassiagoodson/nastassiagoodson.github.io","url":"https://api.github.com/repos/nastassiagoodson/nastassiagoodson.github.io"},"payload":{"push_id":9287928155,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"01e160c5e7fd5520908807cd181811a0d54422ba","before":"68965aa31ca040390f7ba94f2e6cb2e1ba06715a","commits":[{"sha":"01e160c5e7fd5520908807cd181811a0d54422ba","author":{"email":"60201494+nastassiagoodson@users.noreply.github.com","name":"nastassiagoodson"},"message":"Update index.js","distinct":true,"url":"https://api.github.com/repos/nastassiagoodson/nastassiagoodson.github.io/commits/01e160c5e7fd5520908807cd181811a0d54422ba"}]},"public":true,"created_at":"2022-03-07T19:33:32Z"},{"id":"20623203351","type":"PushEvent","actor":{"id":98900860,"login":"Nataliia-urazaeva","display_login":"Nataliia-urazaeva","gravatar_id":"","url":"https://api.github.com/users/Nataliia-urazaeva","avatar_url":"https://avatars.githubusercontent.com/u/98900860?"},"repo":{"id":460859407,"name":"Nataliia-urazaeva/jv-oop-advanced","url":"https://api.github.com/repos/Nataliia-urazaeva/jv-oop-advanced"},"payload":{"push_id":9287928132,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"1e6c55f36ff3dfb36f82999b880f03b4d01ee95d","before":"740ae28efd17aa3fa2ec63acf2009e82439ede1d","commits":[{"sha":"1e6c55f36ff3dfb36f82999b880f03b4d01ee95d","author":{"email":"natasha.uraza@gmail.com","name":"Nataliia Urazaeva"},"message":"first decision","distinct":true,"url":"https://api.github.com/repos/Nataliia-urazaeva/jv-oop-advanced/commits/1e6c55f36ff3dfb36f82999b880f03b4d01ee95d"}]},"public":true,"created_at":"2022-03-07T19:33:32Z"},{"id":"20623203389","type":"WatchEvent","actor":{"id":76534640,"login":"GMac22","display_login":"GMac22","gravatar_id":"","url":"https://api.github.com/users/GMac22","avatar_url":"https://avatars.githubusercontent.com/u/76534640?"},"repo":{"id":413888152,"name":"gurnec/removeddit","url":"https://api.github.com/repos/gurnec/removeddit"},"payload":{"action":"started"},"public":true,"created_at":"2022-03-07T19:33:32Z"},{"id":"20623203387","type":"IssueCommentEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":454852445,"name":"Grimface/windty-test","url":"https://api.github.com/repos/Grimface/windty-test"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/Grimface/windty-test/issues/7","repository_url":"https://api.github.com/repos/Grimface/windty-test","labels_url":"https://api.github.com/repos/Grimface/windty-test/issues/7/labels{/name}","comments_url":"https://api.github.com/repos/Grimface/windty-test/issu ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://2.python-requests.org//en/v0.10.6/api/) in the documentation.

# %%
# Another attribute, what does this show us?
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Mon, 07 Mar 2022 19:38:33 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"d3463af931d6e5b60c76c0ec26dbc1a1bd1f162544c0d7d5e004abae6a68d2b4"', 'Last-Modified': 'Mon, 07 Mar 2022 19:33:32 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1646685512', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'D0F2:6DC1:B19A18:273F599:62265F38'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code
# Out:
# 200

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '20623203324',
#   'type': 'PushEvent',
#   'actor': {'id': 92473363,
#    'login': 'Mofazzal-145',
#    'display_login': 'Mofazzal-145',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mofazzal-145',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92473363?'},
#   'repo': {'id': 467135558,
#    'name': 'Mofazzal-145/js-concepts-for-react',
#    'url': 'https://api.github.com/repos/Mofazzal-145/js-concepts-for-react'},
#   'payload': {'push_id': 9287928128,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3122261f2ee65a3cecce1aff23c75f73545ec83e',
#    'before': 'df0c357f01072f0c09301e5fa408d537ea11a50d',
#    'commits': [{'sha': '3122261f2ee65a3cecce1aff23c75f73545ec83e',
#      'author': {'email': 'md.mofazzalhossain145@gmail.com',
#       'name': 'Mofazzal-145'},
#      'message': 't:string, a:func, s:operator',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mofazzal-145/js-concepts-for-react/commits/3122261f2ee65a3cecce1aff23c75f73545ec83e'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203341',
#   'type': 'PushEvent',
#   'actor': {'id': 60201494,
#    'login': 'nastassiagoodson',
#    'display_login': 'nastassiagoodson',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nastassiagoodson',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60201494?'},
#   'repo': {'id': 465920826,
#    'name': 'nastassiagoodson/nastassiagoodson.github.io',
#    'url': 'https://api.github.com/repos/nastassiagoodson/nastassiagoodson.github.io'},
#   'payload': {'push_id': 9287928155,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '01e160c5e7fd5520908807cd181811a0d54422ba',
#    'before': '68965aa31ca040390f7ba94f2e6cb2e1ba06715a',
#    'commits': [{'sha': '01e160c5e7fd5520908807cd181811a0d54422ba',
#      'author': {'email': '60201494+nastassiagoodson@users.noreply.github.com',
#       'name': 'nastassiagoodson'},
#      'message': 'Update index.js',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nastassiagoodson/nastassiagoodson.github.io/commits/01e160c5e7fd5520908807cd181811a0d54422ba'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203351',
#   'type': 'PushEvent',
#   'actor': {'id': 98900860,
#    'login': 'Nataliia-urazaeva',
#    'display_login': 'Nataliia-urazaeva',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nataliia-urazaeva',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98900860?'},
#   'repo': {'id': 460859407,
#    'name': 'Nataliia-urazaeva/jv-oop-advanced',
#    'url': 'https://api.github.com/repos/Nataliia-urazaeva/jv-oop-advanced'},
#   'payload': {'push_id': 9287928132,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1e6c55f36ff3dfb36f82999b880f03b4d01ee95d',
#    'before': '740ae28efd17aa3fa2ec63acf2009e82439ede1d',
#    'commits': [{'sha': '1e6c55f36ff3dfb36f82999b880f03b4d01ee95d',
#      'author': {'email': 'natasha.uraza@gmail.com',
#       'name': 'Nataliia Urazaeva'},
#      'message': 'first decision',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Nataliia-urazaeva/jv-oop-advanced/commits/1e6c55f36ff3dfb36f82999b880f03b4d01ee95d'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203389',
#   'type': 'WatchEvent',
#   'actor': {'id': 76534640,
#    'login': 'GMac22',
#    'display_login': 'GMac22',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GMac22',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76534640?'},
#   'repo': {'id': 413888152,
#    'name': 'gurnec/removeddit',
#    'url': 'https://api.github.com/repos/gurnec/removeddit'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203387',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 454852445,
#    'name': 'Grimface/windty-test',
#    'url': 'https://api.github.com/repos/Grimface/windty-test'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Grimface/windty-test/issues/7',
#     'repository_url': 'https://api.github.com/repos/Grimface/windty-test',
#     'labels_url': 'https://api.github.com/repos/Grimface/windty-test/issues/7/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Grimface/windty-test/issues/7/comments',
#     'events_url': 'https://api.github.com/repos/Grimface/windty-test/issues/7/events',
#     'html_url': 'https://github.com/Grimface/windty-test/pull/7',
#     'id': 1150778085,
#     'node_id': 'PR_kwDOGxx_Xc4ze4wH',
#     'number': 7,
#     'title': 'Bump postcss from 8.4.5 to 8.4.7',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 3791804292,
#       'node_id': 'LA_kwDOGxx_Xc7iAleE',
#       'url': 'https://api.github.com/repos/Grimface/windty-test/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2022-02-25T19:29:10Z',
#     'updated_at': '2022-03-07T19:33:32Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/Grimface/windty-test/pulls/7',
#      'html_url': 'https://github.com/Grimface/windty-test/pull/7',
#      'diff_url': 'https://github.com/Grimface/windty-test/pull/7.diff',
#      'patch_url': 'https://github.com/Grimface/windty-test/pull/7.patch',
#      'merged_at': None},
#     'body': 'Bumps [postcss](https://github.com/postcss/postcss) from 8.4.5 to 8.4.7.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/postcss/postcss/releases">postcss\'s releases</a>.</em></p>\n<blockquote>\n<h2>8.4.7</h2>\n<ul>\n<li>Fixed <code>Node#warn()</code> type (by <a href="https://github.com/ybiquitous"><code>@\u200bybiquitous</code></a>).</li>\n<li>Fixed comment removal in values after <code>,</code>.</li>\n</ul>\n<h2>8.4.6</h2>\n<ul>\n<li>Prevented comment removing when it change meaning of CSS.</li>\n<li>Fixed parsing space in last semicolon-less CSS Custom Properties.</li>\n<li>Fixed comment cleaning in CSS Custom Properties with space.</li>\n<li>Fixed throwing an error on <code>.root</code> access for plugin-less case.</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/postcss/postcss/blob/main/CHANGELOG.md">postcss\'s changelog</a>.</em></p>\n<blockquote>\n<h2>8.4.7</h2>\n<ul>\n<li>Fixed <code>Node#warn()</code> type (by Masafumi Koba).</li>\n<li>Fixed comment removal in values after <code>,</code>.</li>\n</ul>\n<h2>8.4.6</h2>\n<ul>\n<li>Prevented comment removing when it change meaning of CSS.</li>\n<li>Fixed parsing space in last semicolon-less CSS Custom Properties.</li>\n<li>Fixed comment cleaning in CSS Custom Properties with space.</li>\n<li>Fixed throwing an error on <code>.root</code> access for plugin-less case.</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/postcss/postcss/commit/d533f80b3cb4ef394cc7b523f675828ef7ec8466"><code>d533f80</code></a> Release 8.4.7 version</li>\n<li><a href="https://github.com/postcss/postcss/commit/c50b8a3d8f6e780c8dca4b0233cd47f1b52518ba"><code>c50b8a3</code></a> Update dependencies</li>\n<li><a href="https://github.com/postcss/postcss/commit/0e568948f3d9e5ff83e9b740e17c5abe885d12f3"><code>0e56894</code></a> Merge pull request <a href="https://github-redirect.dependabot.com/postcss/postcss/issues/1722">#1722</a> from ybiquitous/fix-node-warn-return-type</li>\n<li><a href="https://github.com/postcss/postcss/commit/db5b6e1c45b53145413ab3fa6e7b810b18f8d1c9"><code>db5b6e1</code></a> Fix <code>Node#warn()</code> return type</li>\n<li><a href="https://github.com/postcss/postcss/commit/8718e0656e78f96d7812300bc372ff3a574d6fad"><code>8718e06</code></a> Update dependencies</li>\n<li><a href="https://github.com/postcss/postcss/commit/ed054f23da7cdeed4648add89e62aacd4fe23b44"><code>ed054f2</code></a> Fix CI config</li>\n<li><a href="https://github.com/postcss/postcss/commit/2010e2433f27afd5628a5d20555746a96c540496"><code>2010e24</code></a> Fix comment removal after ,</li>\n<li><a href="https://github.com/postcss/postcss/commit/1e246383b645c16253a2ccebce3c51f137254d42"><code>1e24638</code></a> Clean up code</li>\n<li><a href="https://github.com/postcss/postcss/commit/a00876066fa3e5f49f595092dc77b62b98efcfd2"><code>a008760</code></a> Update dependencies</li>\n<li><a href="https://github.com/postcss/postcss/commit/97b06217b5ba8a8d2ace292e62499066df839600"><code>97b0621</code></a> Fix 80 columns line</li>\n<li>Additional commits viewable in <a href="https://github.com/postcss/postcss/compare/8.4.5...8.4.7">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=postcss&package-manager=npm_and_yarn&previous-version=8.4.5&new-version=8.4.7)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<b ...
#     'reactions': {'url': 'https://api.github.com/repos/Grimface/windty-test/issues/7/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/Grimface/windty-test/issues/7/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/Grimface/windty-test/issues/comments/1061057424',
#     'html_url': 'https://github.com/Grimface/windty-test/pull/7#issuecomment-1061057424',
#     'issue_url': 'https://api.github.com/repos/Grimface/windty-test/issues/7',
#     'id': 1061057424,
#     'node_id': 'IC_kwDOGxx_Xc4_PnOQ',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2022-03-07T19:33:32Z',
#     'updated_at': '2022-03-07T19:33:32Z',
#     'author_association': 'NONE',
#     'body': 'Superseded by #9.',
#     'reactions': {'url': 'https://api.github.com/repos/Grimface/windty-test/issues/comments/1061057424/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203367',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 18165255,
#    'login': 'johnnyvaz1',
#    'display_login': 'johnnyvaz1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/johnnyvaz1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18165255?'},
#   'repo': {'id': 463847236,
#    'name': 'johnnyvaz1/desligue-se',
#    'url': 'https://api.github.com/repos/johnnyvaz1/desligue-se'},
#   'payload': {'action': 'opened',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/pulls/2',
#     'id': 873482415,
#     'node_id': 'PR_kwDOG6W_RM40EEiv',
#     'html_url': 'https://github.com/johnnyvaz1/desligue-se/pull/2',
#     'diff_url': 'https://github.com/johnnyvaz1/desligue-se/pull/2.diff',
#     'patch_url': 'https://github.com/johnnyvaz1/desligue-se/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/issues/2',
#     'number': 2,
#     'state': 'open',
#     'locked': False,
#     'title': 'feat: add telegram group',
#     'user': {'login': 'johnnyvaz1',
#      'id': 18165255,
#      'node_id': 'MDQ6VXNlcjE4MTY1MjU1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/18165255?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/johnnyvaz1',
#      'html_url': 'https://github.com/johnnyvaz1',
#      'followers_url': 'https://api.github.com/users/johnnyvaz1/followers',
#      'following_url': 'https://api.github.com/users/johnnyvaz1/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/johnnyvaz1/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/johnnyvaz1/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/johnnyvaz1/subscriptions',
#      'organizations_url': 'https://api.github.com/users/johnnyvaz1/orgs',
#      'repos_url': 'https://api.github.com/users/johnnyvaz1/repos',
#      'events_url': 'https://api.github.com/users/johnnyvaz1/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/johnnyvaz1/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2022-03-07T19:33:32Z',
#     'updated_at': '2022-03-07T19:33:32Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/statuses/0c0587ae7d2f6b8bf1365e766c77faa8aa341886',
#     'head': {'label': 'johnnyvaz1:johnny',
#      'ref': 'johnny',
#      'sha': '0c0587ae7d2f6b8bf1365e766c77faa8aa341886',
#      'user': {'login': 'johnnyvaz1',
#       'id': 18165255,
#       'node_id': 'MDQ6VXNlcjE4MTY1MjU1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/18165255?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/johnnyvaz1',
#       'html_url': 'https://github.com/johnnyvaz1',
#       'followers_url': 'https://api.github.com/users/johnnyvaz1/followers',
#       'following_url': 'https://api.github.com/users/johnnyvaz1/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/johnnyvaz1/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/johnnyvaz1/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/johnnyvaz1/subscriptions',
#       'organizations_url': 'https://api.github.com/users/johnnyvaz1/orgs',
#       'repos_url': 'https://api.github.com/users/johnnyvaz1/repos',
#       'events_url': 'https://api.github.com/users/johnnyvaz1/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/johnnyvaz1/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 463847236,
#       'node_id': 'R_kgDOG6W_RA',
#       'name': 'desligue-se',
#       'full_name': 'johnnyvaz1/desligue-se',
#       'private': False,
#       'owner': {'login': 'johnnyvaz1',
#        'id': 18165255,
#        'node_id': 'MDQ6VXNlcjE4MTY1MjU1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/18165255?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/johnnyvaz1',
#        'html_url': 'https://github.com/johnnyvaz1',
#        'followers_url': 'https://api.github.com/users/johnnyvaz1/followers',
#        'following_url': 'https://api.github.com/users/johnnyvaz1/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/johnnyvaz1/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/johnnyvaz1/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/johnnyvaz1/subscriptions',
#        'organizations_url': 'https://api.github.com/users/johnnyvaz1/orgs',
#        'repos_url': 'https://api.github.com/users/johnnyvaz1/repos',
#        'events_url': 'https://api.github.com/users/johnnyvaz1/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/johnnyvaz1/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/johnnyvaz1/desligue-se',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/johnnyvaz1/desligue-se',
#       'forks_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/forks',
#       'keys_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/teams',
#       'hooks_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/hooks',
#       'issue_events_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/events',
#       'assignees_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/tags',
#       'blobs_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/languages',
#       'stargazers_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/stargazers',
#       'contributors_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/contributors',
#       'subscribers_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/subscribers',
#       'subscription_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/subscription',
#       'commits_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/merges',
#       'archive_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/downloads',
#       'issues_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/deployments',
#       'created_at': '2022-02-26T12:31:16Z',
#       'updated_at': '2022-02-26T12:34:48Z',
#       'pushed_at': '2022-03-07T19:33:32Z',
#       'git_url': 'git://github.com/johnnyvaz1/desligue-se.git',
#       'ssh_url': 'git@github.com:johnnyvaz1/desligue-se.git',
#       'clone_url': 'https://github.com/johnnyvaz1/desligue-se.git',
#       'svn_url': 'https://github.com/johnnyvaz1/desligue-se',
#       'homepage': None,
#       'size': 794,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Vue',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'johnnyvaz1:master',
#      'ref': 'master',
#      'sha': 'd97ef6e387d274b94e848b08688f6a621b5fe6cd',
#      'user': {'login': 'johnnyvaz1',
#       'id': 18165255,
#       'node_id': 'MDQ6VXNlcjE4MTY1MjU1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/18165255?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/johnnyvaz1',
#       'html_url': 'https://github.com/johnnyvaz1',
#       'followers_url': 'https://api.github.com/users/johnnyvaz1/followers',
#       'following_url': 'https://api.github.com/users/johnnyvaz1/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/johnnyvaz1/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/johnnyvaz1/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/johnnyvaz1/subscriptions',
#       'organizations_url': 'https://api.github.com/users/johnnyvaz1/orgs',
#       'repos_url': 'https://api.github.com/users/johnnyvaz1/repos',
#       'events_url': 'https://api.github.com/users/johnnyvaz1/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/johnnyvaz1/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 463847236,
#       'node_id': 'R_kgDOG6W_RA',
#       'name': 'desligue-se',
#       'full_name': 'johnnyvaz1/desligue-se',
#       'private': False,
#       'owner': {'login': 'johnnyvaz1',
#        'id': 18165255,
#        'node_id': 'MDQ6VXNlcjE4MTY1MjU1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/18165255?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/johnnyvaz1',
#        'html_url': 'https://github.com/johnnyvaz1',
#        'followers_url': 'https://api.github.com/users/johnnyvaz1/followers',
#        'following_url': 'https://api.github.com/users/johnnyvaz1/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/johnnyvaz1/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/johnnyvaz1/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/johnnyvaz1/subscriptions',
#        'organizations_url': 'https://api.github.com/users/johnnyvaz1/orgs',
#        'repos_url': 'https://api.github.com/users/johnnyvaz1/repos',
#        'events_url': 'https://api.github.com/users/johnnyvaz1/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/johnnyvaz1/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/johnnyvaz1/desligue-se',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/johnnyvaz1/desligue-se',
#       'forks_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/forks',
#       'keys_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/teams',
#       'hooks_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/hooks',
#       'issue_events_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/events',
#       'assignees_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/tags',
#       'blobs_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/languages',
#       'stargazers_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/stargazers',
#       'contributors_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/contributors',
#       'subscribers_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/subscribers',
#       'subscription_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/subscription',
#       'commits_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/merges',
#       'archive_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/downloads',
#       'issues_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/johnnyvaz1/desligue-se/deployments',
#       'created_at': '2022-02-26T12:31:16Z',
#       'updated_at': '2022-02-26T12:34:48Z',
#       'pushed_at': '2022-03-07T19:33:32Z',
#       'git_url': 'git://github.com/johnnyvaz1/desligue-se.git',
#       'ssh_url': 'git@github.com:johnnyvaz1/desligue-se.git',
#       'clone_url': 'https://github.com/johnnyvaz1/desligue-se.git',
#       'svn_url': 'https://github.com/johnnyvaz1/desligue-se',
#       'homepage': None,
#       'size': 794,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Vue',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/johnnyvaz1/desligue-se/pulls/2'},
#      'html': {'href': 'https://github.com/johnnyvaz1/desligue-se/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/johnnyvaz1/desligue-se/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/johnnyvaz1/desligue-se/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/johnnyvaz1/desligue-se/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/johnnyvaz1/desligue-se/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/johnnyvaz1/desligue-se/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/johnnyvaz1/desligue-se/statuses/0c0587ae7d2f6b8bf1365e766c77faa8aa341886'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 65,
#     'deletions': 90,
#     'changed_files': 5}},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203376',
#   'type': 'DeleteEvent',
#   'actor': {'id': 93272879,
#    'login': 'zsswewsssw',
#    'display_login': 'zsswewsssw',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zsswewsssw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93272879?'},
#   'repo': {'id': 421866659,
#    'name': 'zsswewsssw/zssweaspic',
#    'url': 'https://api.github.com/repos/zsswewsssw/zssweaspic'},
#   'payload': {'ref': 'latest', 'ref_type': 'tag', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203356',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 29777165,
#    'login': 'NouamaneTazi',
#    'display_login': 'NouamaneTazi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NouamaneTazi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29777165?'},
#   'repo': {'id': 24245737,
#    'name': 'projectmesa/mesa',
#    'url': 'https://api.github.com/repos/projectmesa/mesa'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/projectmesa/mesa/issues/1178',
#     'repository_url': 'https://api.github.com/repos/projectmesa/mesa',
#     'labels_url': 'https://api.github.com/repos/projectmesa/mesa/issues/1178/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/projectmesa/mesa/issues/1178/comments',
#     'events_url': 'https://api.github.com/repos/projectmesa/mesa/issues/1178/events',
#     'html_url': 'https://github.com/projectmesa/mesa/pull/1178',
#     'id': 1159654163,
#     'node_id': 'PR_kwDOAXH16c4z9Kdf',
#     'number': 1178,
#     'title': 'Add "Grass" curve to wolf_sheep example chart',
#     'user': {'login': 'NouamaneTazi',
#      'id': 29777165,
#      'node_id': 'MDQ6VXNlcjI5Nzc3MTY1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/29777165?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/NouamaneTazi',
#      'html_url': 'https://github.com/NouamaneTazi',
#      'followers_url': 'https://api.github.com/users/NouamaneTazi/followers',
#      'following_url': 'https://api.github.com/users/NouamaneTazi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/NouamaneTazi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/NouamaneTazi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/NouamaneTazi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/NouamaneTazi/orgs',
#      'repos_url': 'https://api.github.com/users/NouamaneTazi/repos',
#      'events_url': 'https://api.github.com/users/NouamaneTazi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/NouamaneTazi/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 10,
#     'created_at': '2022-03-04T13:35:19Z',
#     'updated_at': '2022-03-07T19:33:32Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/projectmesa/mesa/pulls/1178',
#      'html_url': 'https://github.com/projectmesa/mesa/pull/1178',
#      'diff_url': 'https://github.com/projectmesa/mesa/pull/1178.diff',
#      'patch_url': 'https://github.com/projectmesa/mesa/pull/1178.patch',
#      'merged_at': None},
#     'body': '![image](https://user-images.githubusercontent.com/29777165/156922194-9ca43464-682d-45c1-9dc2-de8402b8eb8d.png)',
#     'reactions': {'url': 'https://api.github.com/repos/projectmesa/mesa/issues/1178/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/projectmesa/mesa/issues/1178/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/projectmesa/mesa/issues/comments/1061057419',
#     'html_url': 'https://github.com/projectmesa/mesa/pull/1178#issuecomment-1061057419',
#     'issue_url': 'https://api.github.com/repos/projectmesa/mesa/issues/1178',
#     'id': 1061057419,
#     'node_id': 'IC_kwDOAXH16c4_PnOL',
#     'user': {'login': 'NouamaneTazi',
#      'id': 29777165,
#      'node_id': 'MDQ6VXNlcjI5Nzc3MTY1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/29777165?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/NouamaneTazi',
#      'html_url': 'https://github.com/NouamaneTazi',
#      'followers_url': 'https://api.github.com/users/NouamaneTazi/followers',
#      'following_url': 'https://api.github.com/users/NouamaneTazi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/NouamaneTazi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/NouamaneTazi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/NouamaneTazi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/NouamaneTazi/orgs',
#      'repos_url': 'https://api.github.com/users/NouamaneTazi/repos',
#      'events_url': 'https://api.github.com/users/NouamaneTazi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/NouamaneTazi/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-03-07T19:33:32Z',
#     'updated_at': '2022-03-07T19:33:32Z',
#     'author_association': 'NONE',
#     'body': '> There is a Readme.md in the `wolf_sheep/` folder. In this readme, there is a list of files and explanation for what each does. And so, the scheduler.py needs to be documented there.\r\n> \r\n> Other than this, LGTM. Make sure to squash the commits into 1 commit.\r\n\r\nFixed. And yes, the commits can be squashed before merging',
#     'reactions': {'url': 'https://api.github.com/repos/projectmesa/mesa/issues/comments/1061057419/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z',
#   'org': {'id': 8754505,
#    'login': 'projectmesa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/projectmesa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8754505?'}},
#  {'id': '20623203327',
#   'type': 'PushEvent',
#   'actor': {'id': 69827768,
#    'login': 'jjlange',
#    'display_login': 'jjlange',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jjlange',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69827768?'},
#   'repo': {'id': 224016452,
#    'name': 'jjlange/Tapzie.Web',
#    'url': 'https://api.github.com/repos/jjlange/Tapzie.Web'},
#   'payload': {'push_id': 9287928135,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '10f33b37eeba81d2913896b9d5d58eb2bbbacc21',
#    'before': 'b16d8addeeeb592304866e7fa0efbf510fb650cc',
#    'commits': [{'sha': '10f33b37eeba81d2913896b9d5d58eb2bbbacc21',
#      'author': {'email': 'langejustin@icloud.com', 'name': 'Justin Lange'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jjlange/Tapzie.Web/commits/10f33b37eeba81d2913896b9d5d58eb2bbbacc21'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203361',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 16845933,
#    'login': 'Ethan-DeBandi99',
#    'display_login': 'Ethan-DeBandi99',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ethan-DeBandi99',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16845933?'},
#   'repo': {'id': 177168929,
#    'name': 'Bears-R-Us/arkouda',
#    'url': 'https://api.github.com/repos/Bears-R-Us/arkouda'},
#   'payload': {'action': 'created',
#    'review': {'id': 902160402,
#     'node_id': 'PRR_kwDOCo9iIc41xeAS',
#     'user': {'login': 'Ethan-DeBandi99',
#      'id': 16845933,
#      'node_id': 'MDQ6VXNlcjE2ODQ1OTMz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/16845933?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Ethan-DeBandi99',
#      'html_url': 'https://github.com/Ethan-DeBandi99',
#      'followers_url': 'https://api.github.com/users/Ethan-DeBandi99/followers',
#      'following_url': 'https://api.github.com/users/Ethan-DeBandi99/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Ethan-DeBandi99/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Ethan-DeBandi99/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Ethan-DeBandi99/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Ethan-DeBandi99/orgs',
#      'repos_url': 'https://api.github.com/users/Ethan-DeBandi99/repos',
#      'events_url': 'https://api.github.com/users/Ethan-DeBandi99/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Ethan-DeBandi99/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'commit_id': '72228f80cf7fb27c28e4fbf3293f56fdb3335e38',
#     'submitted_at': '2022-03-07T19:33:32Z',
#     'state': 'commented',
#     'html_url': 'https://github.com/Bears-R-Us/arkouda/pull/1177#pullrequestreview-902160402',
#     'pull_request_url': 'https://api.github.com/repos/Bears-R-Us/arkouda/pulls/1177',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'html': {'href': 'https://github.com/Bears-R-Us/arkouda/pull/1177#pullrequestreview-902160402'},
#      'pull_request': {'href': 'https://api.github.com/repos/Bears-R-Us/arkouda/pulls/1177'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/Bears-R-Us/arkouda/pulls/1177',
#     'id': 871853976,
#     'node_id': 'PR_kwDOCo9iIc4z92-Y',
#     'html_url': 'https://github.com/Bears-R-Us/arkouda/pull/1177',
#     'diff_url': 'https://github.com/Bears-R-Us/arkouda/pull/1177.diff',
#     'patch_url': 'https://github.com/Bears-R-Us/arkouda/pull/1177.patch',
#     'issue_url': 'https://api.github.com/repos/Bears-R-Us/arkouda/issues/1177',
#     'number': 1177,
#     'state': 'open',
#     'locked': False,
#     'title': 'Closes #1165 drop on axis',
#     'user': {'login': 'Ethan-DeBandi99',
#      'id': 16845933,
#      'node_id': 'MDQ6VXNlcjE2ODQ1OTMz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/16845933?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Ethan-DeBandi99',
#      'html_url': 'https://github.com/Ethan-DeBandi99',
#      'followers_url': 'https://api.github.com/users/Ethan-DeBandi99/followers',
#      'following_url': 'https://api.github.com/users/Ethan-DeBandi99/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Ethan-DeBandi99/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Ethan-DeBandi99/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Ethan-DeBandi99/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Ethan-DeBandi99/orgs',
#      'repos_url': 'https://api.github.com/users/Ethan-DeBandi99/repos',
#      'events_url': 'https://api.github.com/users/Ethan-DeBandi99/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Ethan-DeBandi99/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'This PR (closes #1165):\r\n\r\nPandas `DataFrame.drop()` utilizes an `axis` parameter to trigger drops on rows or columns. This functionality has been added to Arkouda here.\r\n\r\n- `axis` should be 0 or 1. 0 = rows, 1 = columns.\r\n- Tests have been added to: validate column drop using axis param, validate row drop, validate exception cases are caught as expected.\r\n- Documentation has been updated to include `.drop()` for `DataFrame`. \r\n\r\nFor testing I added functions to build an `ak.DataFrame` and a `pd.DataFrame`. I only implemented this for drop because there is an existing issue in to handle this for all tests.\r\n\r\nThis functionality is currently only available in-place at this time. ',
#     'created_at': '2022-03-04T17:11:51Z',
#     'updated_at': '2022-03-07T19:33:32Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'd0cd9f2ac6e126b1c4ded08ceee53d60aa41b83d',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'reuster986',
#       'id': 18542793,
#       'node_id': 'MDQ6VXNlcjE4NTQyNzkz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/18542793?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/reuster986',
#       'html_url': 'https://github.com/reuster986',
#       'followers_url': 'https://api.github.com/users/reuster986/followers',
#       'following_url': 'https://api.github.com/users/reuster986/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/reuster986/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/reuster986/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/reuster986/subscriptions',
#       'organizations_url': 'https://api.github.com/users/reuster986/orgs',
#       'repos_url': 'https://api.github.com/users/reuster986/repos',
#       'events_url': 'https://api.github.com/users/reuster986/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/reuster986/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Bears-R-Us/arkouda/pulls/1177/commits',
#     'review_comments_url': 'https://api.github.com/repos/Bears-R-Us/arkouda/pulls/1177/comments',
#     'review_comment_url': 'https://api.github.com/repos/Bears-R-Us/arkouda/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Bears-R-Us/arkouda/issues/1177/comments',
#     'statuses_url': 'https://api.github.com/repos/Bears-R-Us/arkouda/statuses/39675009584845b7a20b10acf1d30edbfcebd8c5',
#     'head': {'label': 'Ethan-DeBandi99:1165_Drop_on_Axis',
#      'ref': '1165_Drop_on_Axis',
#      'sha': '39675009584845b7a20b10acf1d30edbfcebd8c5',
#      'user': {'login': 'Ethan-DeBandi99',
#       'id': 16845933,
#       'node_id': 'MDQ6VXNlcjE2ODQ1OTMz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/16845933?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Ethan-DeBandi99',
#       'html_url': 'https://github.com/Ethan-DeBandi99',
#       'followers_url': 'https://api.github.com/users/Ethan-DeBandi99/followers',
#       'following_url': 'https://api.github.com/users/Ethan-DeBandi99/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Ethan-DeBandi99/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Ethan-DeBandi99/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Ethan-DeBandi99/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Ethan-DeBandi99/orgs',
#       'repos_url': 'https://api.github.com/users/Ethan-DeBandi99/repos',
#       'events_url': 'https://api.github.com/users/Ethan-DeBandi99/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Ethan-DeBandi99/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 459257589,
#       'node_id': 'R_kgDOG1-29Q',
#       'name': 'arkouda',
#       'full_name': 'Ethan-DeBandi99/arkouda',
#       'private': False,
#       'owner': {'login': 'Ethan-DeBandi99',
#        'id': 16845933,
#        'node_id': 'MDQ6VXNlcjE2ODQ1OTMz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/16845933?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Ethan-DeBandi99',
#        'html_url': 'https://github.com/Ethan-DeBandi99',
#        'followers_url': 'https://api.github.com/users/Ethan-DeBandi99/followers',
#        'following_url': 'https://api.github.com/users/Ethan-DeBandi99/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Ethan-DeBandi99/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Ethan-DeBandi99/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Ethan-DeBandi99/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Ethan-DeBandi99/orgs',
# ...
#        'gists_url': 'https://api.github.com/users/test-organization-kkjeer/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/test-organization-kkjeer/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/test-organization-kkjeer/subscriptions',
#        'organizations_url': 'https://api.github.com/users/test-organization-kkjeer/orgs',
#        'repos_url': 'https://api.github.com/users/test-organization-kkjeer/repos',
#        'events_url': 'https://api.github.com/users/test-organization-kkjeer/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/test-organization-kkjeer/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/test-organization-kkjeer/app-test-2',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2',
#       'forks_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/forks',
#       'keys_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/teams',
#       'hooks_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/hooks',
#       'issue_events_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/events',
#       'assignees_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/tags',
#       'blobs_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/languages',
#       'stargazers_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/stargazers',
#       'contributors_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/contributors',
#       'subscribers_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/subscribers',
#       'subscription_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/subscription',
#       'commits_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/merges',
#       'archive_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/downloads',
#       'issues_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/deployments',
#       'created_at': '2021-06-22T20:45:26Z',
#       'updated_at': '2022-01-11T03:14:53Z',
#       'pushed_at': '2022-03-07T19:33:31Z',
#       'git_url': 'git://github.com/test-organization-kkjeer/app-test-2.git',
#       'ssh_url': 'git@github.com:test-organization-kkjeer/app-test-2.git',
#       'clone_url': 'https://github.com/test-organization-kkjeer/app-test-2.git',
#       'svn_url': 'https://github.com/test-organization-kkjeer/app-test-2',
#       'homepage': None,
#       'size': 19682,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 12,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 12,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/pulls/85108'},
#      'html': {'href': 'https://github.com/test-organization-kkjeer/app-test-2/pull/85108'},
#      'issue': {'href': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/issues/85108'},
#      'comments': {'href': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/issues/85108/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/pulls/85108/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/pulls/85108/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/statuses/b8602dc6025a6beab5df780a5ea495e7a70ab570'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z',
#   'org': {'id': 47997193,
#    'login': 'test-organization-kkjeer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/test-organization-kkjeer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47997193?'}},
#  {'id': '20623203251',
#   'type': 'PushEvent',
#   'actor': {'id': 101117629,
#    'login': 'K4rma13',
#    'display_login': 'K4rma13',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/K4rma13',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101117629?'},
#   'repo': {'id': 467193657,
#    'name': 'K4rma13/programacao-imperativa',
#    'url': 'https://api.github.com/repos/K4rma13/programacao-imperativa'},
#   'payload': {'push_id': 9287928107,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3450fe5bcfd3de88928463fd285c37969a0e7c07',
#    'before': '8b6db8a5542a46313f874e2588e383dd5c5b64db',
#    'commits': [{'sha': '3450fe5bcfd3de88928463fd285c37969a0e7c07',
#      'author': {'email': 'pedrodviana@hotmail.com', 'name': 'K4rma13'},
#      'message': 'Added',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/K4rma13/programacao-imperativa/commits/3450fe5bcfd3de88928463fd285c37969a0e7c07'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203261',
#   'type': 'PushEvent',
#   'actor': {'id': 86326137,
#    'login': 'bot-monkey-7',
#    'display_login': 'bot-monkey-7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bot-monkey-7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/86326137?'},
#   'repo': {'id': 379396407,
#    'name': 'test-organization-kkjeer/app-test-2',
#    'url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2'},
#   'payload': {'push_id': 9287928099,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/monkey-branch-97k82i',
#    'head': 'b8602dc6025a6beab5df780a5ea495e7a70ab570',
#    'before': '1f0979281dac68c10963c479397199b8824df503',
#    'commits': [{'sha': 'b8602dc6025a6beab5df780a5ea495e7a70ab570',
#      'author': {'email': '86326137+bot-monkey-7@users.noreply.github.com',
#       'name': 'bot-monkey-7'},
#      'message': 'Monkey commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/commits/b8602dc6025a6beab5df780a5ea495e7a70ab570'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z',
#   'org': {'id': 47997193,
#    'login': 'test-organization-kkjeer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/test-organization-kkjeer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47997193?'}},
#  {'id': '20623203230',
#   'type': 'PushEvent',
#   'actor': {'id': 37955572,
#    'login': 'ivdevelopment',
#    'display_login': 'ivdevelopment',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ivdevelopment',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37955572?'},
#   'repo': {'id': 467199962,
#    'name': 'ivdevelopment/qr-code-component-challenge',
#    'url': 'https://api.github.com/repos/ivdevelopment/qr-code-component-challenge'},
#   'payload': {'push_id': 9287928078,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8e0be3467188cfd05ba544b2c815e0dd7ddaef5e',
#    'before': 'b7cd0f977f4d2a4f86e917e77fe82029f4fe2012',
#    'commits': [{'sha': '8e0be3467188cfd05ba544b2c815e0dd7ddaef5e',
#      'author': {'email': 'ianverlinden1.iv@gmail.com', 'name': 'IanV'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ivdevelopment/qr-code-component-challenge/commits/8e0be3467188cfd05ba544b2c815e0dd7ddaef5e'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203256',
#   'type': 'PushEvent',
#   'actor': {'id': 396596,
#    'login': 'FatConan',
#    'display_login': 'FatConan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FatConan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/396596?'},
#   'repo': {'id': 169561916,
#    'name': 'FatConan/formic-acid',
#    'url': 'https://api.github.com/repos/FatConan/formic-acid'},
#   'payload': {'push_id': 9287928071,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/scala-2.12',
#    'head': 'c34866b6e50b29a5b6c270edf9041399eafcb21b',
#    'before': 'cea19fe37c457d733ef022bd77084d7dbf185aaf',
#    'commits': [{'sha': 'c34866b6e50b29a5b6c270edf9041399eafcb21b',
#      'author': {'email': 'iancapacitated@gmail.com', 'name': 'Ian Usher'},
#      'message': 'Correcting cell type presendence in renderer',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/FatConan/formic-acid/commits/c34866b6e50b29a5b6c270edf9041399eafcb21b'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203226',
#   'type': 'PushEvent',
#   'actor': {'id': 88229217,
#    'login': 'Rameez10-REAL',
#    'display_login': 'Rameez10-REAL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rameez10-REAL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88229217?'},
#   'repo': {'id': 443008281,
#    'name': 'Rameez10-REAL/Rameez10-Linux-Gaming-Easy',
#    'url': 'https://api.github.com/repos/Rameez10-REAL/Rameez10-Linux-Gaming-Easy'},
#   'payload': {'push_id': 9287928102,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2041aac12947d4e23b19272605a9ee2d6d4fe393',
#    'before': '6702c171baaa4f9ebab9a7557f613ab44fa3bae8',
#    'commits': [{'sha': '2041aac12947d4e23b19272605a9ee2d6d4fe393',
#      'author': {'email': 'Rameezmajid10@outlook.com', 'name': 'Rameez10'},
#      'message': 'Update Gaming.sh',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Rameez10-REAL/Rameez10-Linux-Gaming-Easy/commits/2041aac12947d4e23b19272605a9ee2d6d4fe393'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203232',
#   'type': 'PushEvent',
#   'actor': {'id': 65091038,
#    'login': 'archlinux-github',
#    'display_login': 'archlinux-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/archlinux-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65091038?'},
#   'repo': {'id': 281500287,
#    'name': 'archlinux/svntogit-community',
#    'url': 'https://api.github.com/repos/archlinux/svntogit-community'},
#   'payload': {'push_id': 9287928051,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/packages/intel-media-sdk',
#    'head': 'e21bfeb693fb47df2db71df17146f5daf6e2a287',
#    'before': '148f9d19375dd96f6453f698c34c564cfd98afc4',
#    'commits': [{'sha': 'e21bfeb693fb47df2db71df17146f5daf6e2a287',
#      'author': {'email': 'dbermond@9fca08f4-af9d-4005-b8df-a31f2cc04f65',
#       'name': 'dbermond'},
#      'message': 'db-move: moved intel-media-sdk from [community-testing] to [community] (x86_64)\n\ngit-svn-id: file:///srv/repos/svn-community/svn@1144850 9fca08f4-af9d-4005-b8df-a31f2cc04f65',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/archlinux/svntogit-community/commits/e21bfeb693fb47df2db71df17146f5daf6e2a287'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z',
#   'org': {'id': 4673648,
#    'login': 'archlinux',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/archlinux',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4673648?'}},
#  {'id': '20623203225',
#   'type': 'PushEvent',
#   'actor': {'id': 50153175,
#    'login': 'zage96',
#    'display_login': 'zage96',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zage96',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50153175?'},
#   'repo': {'id': 467228253,
#    'name': 'zage96/Android_Studio_projects',
#    'url': 'https://api.github.com/repos/zage96/Android_Studio_projects'},
#   'payload': {'push_id': 9287928090,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd9ca9834249939ab226af49e3ff3795affc43cdc',
#    'before': '4d9f1e2b6bab92556f1d917d3df8ae3a44b9d207',
#    'commits': [{'sha': 'd9ca9834249939ab226af49e3ff3795affc43cdc',
#      'author': {'email': '50153175+zage96@users.noreply.github.com',
#       'name': 'Enrique Zaragoza'},
#      'message': 'Create README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zage96/Android_Studio_projects/commits/d9ca9834249939ab226af49e3ff3795affc43cdc'}]},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'},
#  {'id': '20623203245',
#   'type': 'CreateEvent',
#   'actor': {'id': 20878242,
#    'login': 'akclassic',
#    'display_login': 'akclassic',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/akclassic',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20878242?'},
#   'repo': {'id': 467232499,
#    'name': 'akclassic/LearnGit',
#    'url': 'https://api.github.com/repos/akclassic/LearnGit'},
#   'payload': {'ref': 'featureV1',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Repo for session',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-03-07T19:33:32Z'}]

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception
# - A Timeout exception will be raised if a request times out
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %% [markdown]
# # Gotta Catch 'Em All! Using the Pokemon API
#
# https://pokeapi.co/
#
# Nice place to start because there's no login details or credentials to fuss with
#
# For now, just want to explore grabbing the Types of different Pokemon.
#
# Useful documentation links:
# - Pokemon endpoint: https://pokeapi.co/docs/v2#pokemon
#     - `https://pokeapi.co/api/v2/pokemon/{id or name}/`
# - Type endpoint: https://pokeapi.co/docs/v2#types
#     - `https://pokeapi.co/api/v2/type/{id or name}/`

# %% [markdown]
# ### Start by exploring the response from the Pokemon endpoint
#
# Going to start with Charmander, pokemon #4, cause he's one of my favorites
#
# <img src="https://i.pinimg.com/originals/e7/0e/d0/e70ed0b54f9230c56c2e3bd2958d68a4.jpg" alt="adorable charmander found via pinterest" width=150>
#
# [Image Source](https://www.pinterest.com/pin/419045940312305352/)

# %%
# First, what endpoint url are we using?
base_poke_url = 'https://pokeapi.co/api/v2/pokemon/'

# %%
# How does that need to adapt for charmander?
charmander_url = base_poke_url + '4/'
# charmander_url = base_poke_url + 'charmander/'
charmander_url
# Out:
# 'https://pokeapi.co/api/v2/pokemon/4/'

# %%
# Check the status code, will this work?
resp = requests.get(charmander_url)
resp.status_code
# Out:
# 200

# %%
# Now let's actually get the response (as a json)
resp.json()
# Out:
# {'abilities': [{'ability': {'name': 'blaze',
#     'url': 'https://pokeapi.co/api/v2/ability/66/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'solar-power',
#     'url': 'https://pokeapi.co/api/v2/ability/94/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 62,
#  'forms': [{'name': 'charmander',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/4/'}],
#  'game_indices': [{'game_index': 176,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 176,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 176,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 4,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 4,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 4,
#    'version': {'name': 'crystal',
#     'url': 'https://pokeapi.co/api/v2/version/6/'}},
#   {'game_index': 4,
#    'version': {'name': 'ruby', 'url': 'https://pokeapi.co/api/v2/version/7/'}},
#   {'game_index': 4,
#    'version': {'name': 'sapphire',
#     'url': 'https://pokeapi.co/api/v2/version/8/'}},
#   {'game_index': 4,
#    'version': {'name': 'emerald',
#     'url': 'https://pokeapi.co/api/v2/version/9/'}},
#   {'game_index': 4,
#    'version': {'name': 'firered',
#     'url': 'https://pokeapi.co/api/v2/version/10/'}},
#   {'game_index': 4,
#    'version': {'name': 'leafgreen',
#     'url': 'https://pokeapi.co/api/v2/version/11/'}},
#   {'game_index': 4,
#    'version': {'name': 'diamond',
#     'url': 'https://pokeapi.co/api/v2/version/12/'}},
#   {'game_index': 4,
#    'version': {'name': 'pearl',
#     'url': 'https://pokeapi.co/api/v2/version/13/'}},
#   {'game_index': 4,
#    'version': {'name': 'platinum',
#     'url': 'https://pokeapi.co/api/v2/version/14/'}},
#   {'game_index': 4,
#    'version': {'name': 'heartgold',
#     'url': 'https://pokeapi.co/api/v2/version/15/'}},
#   {'game_index': 4,
#    'version': {'name': 'soulsilver',
#     'url': 'https://pokeapi.co/api/v2/version/16/'}},
#   {'game_index': 4,
#    'version': {'name': 'black',
#     'url': 'https://pokeapi.co/api/v2/version/17/'}},
#   {'game_index': 4,
#    'version': {'name': 'white',
#     'url': 'https://pokeapi.co/api/v2/version/18/'}},
#   {'game_index': 4,
#    'version': {'name': 'black-2',
#     'url': 'https://pokeapi.co/api/v2/version/21/'}},
#   {'game_index': 4,
#    'version': {'name': 'white-2',
#     'url': 'https://pokeapi.co/api/v2/version/22/'}}],
#  'height': 6,
#  'held_items': [],
#  'id': 4,
#  'is_default': True,
#  'location_area_encounters': 'https://pokeapi.co/api/v2/pokemon/4/encounters',
#  'moves': [{'move': {'name': 'mega-punch',
#     'url': 'https://pokeapi.co/api/v2/move/5/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'fire-punch', 'url': 'https://pokeapi.co/api/v2/move/7/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'thunder-punch',
#     'url': 'https://pokeapi.co/api/v2/move/9/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'scratch', 'url': 'https://pokeapi.co/api/v2/move/10/'},
#    'version_group_details': [{'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'swords-dance',
#     'url': 'https://pokeapi.co/api/v2/move/14/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'cut', 'url': 'https://pokeapi.co/api/v2/move/15/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}}]},
#   {'move': {'name': 'wing-attack',
#     'url': 'https://pokeapi.co/api/v2/move/17/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'mega-kick', 'url': 'https://pokeapi.co/api/v2/move/25/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'headbutt', 'url': 'https://pokeapi.co/api/v2/move/29/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}}]},
#   {'move': {'name': 'body-slam', 'url': 'https://pokeapi.co/api/v2/move/34/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'take-down', 'url': 'https://pokeapi.co/api/v2/move/36/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}}]},
#   {'move': {'name': 'double-edge',
#     'url': 'https://pokeapi.co/api/v2/move/38/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}}]},
#   {'move': {'name': 'leer', 'url': 'https://pokeapi.co/api/v2/move/43/'},
#    'version_group_details': [{'level_learned_at': 15,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 15,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}}]},
#   {'move': {'name': 'bite', 'url': 'https://pokeapi.co/api/v2/move/44/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'growl', 'url': 'https://pokeapi.co/api/v2/move/45/'},
#    'version_group_details': [{'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 4,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 1,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'ember', 'url': 'https://pokeapi.co/api/v2/move/52/'},
#    'version_group_details': [{'level_learned_at': 9,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 9,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'colosseum',
#       'url': 'https://pokeapi.co/api/v2/version-group/12/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'xd',
#       'url': 'https://pokeapi.co/api/v2/version-group/13/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-2-white-2',
#       'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 7,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 13,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#       'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#     {'level_learned_at': 4,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'flamethrower',
#     'url': 'https://pokeapi.co/api/v2/move/53/'},
#    'version_group_details': [{'level_learned_at': 38,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'red-blue',
#       'url': 'https://pokeapi.co/api/v2/version-group/1/'}},
#     {'level_learned_at': 38,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'yellow',
#       'url': 'https://pokeapi.co/api/v2/version-group/2/'}},
#     {'level_learned_at': 31,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'gold-silver',
#       'url': 'https://pokeapi.co/api/v2/version-group/3/'}},
#     {'level_learned_at': 31,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'tutor',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'},
#      'version_group': {'name': 'crystal',
#       'url': 'https://pokeapi.co/api/v2/version-group/4/'}},
#     {'level_learned_at': 31,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'ruby-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#     {'level_learned_at': 31,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'emerald',
#       'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#     {'level_learned_at': 31,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'firered-leafgreen',
#       'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#     {'level_learned_at': 34,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'diamond-pearl',
#       'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#     {'level_learned_at': 34,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'platinum',
#       'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#     {'level_learned_at': 34,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'heartgold-soulsilver',
#       'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#     {'level_learned_at': 37,
#      'move_learn_method': {'name': 'level-up',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/1/'},
#      'version_group': {'name': 'black-white',
#       'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
# ...
#      'move_learn_method': {'name': 'egg',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'work-up', 'url': 'https://pokeapi.co/api/v2/move/526/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sword-shield',
#       'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]},
#   {'move': {'name': 'confide', 'url': 'https://pokeapi.co/api/v2/move/590/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'sun-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'ultra-sun-ultra-moon',
#       'url': 'https://pokeapi.co/api/v2/version-group/18/'}}]},
#   {'move': {'name': 'power-up-punch',
#     'url': 'https://pokeapi.co/api/v2/move/612/'},
#    'version_group_details': [{'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'x-y',
#       'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#     {'level_learned_at': 0,
#      'move_learn_method': {'name': 'machine',
#       'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'},
#      'version_group': {'name': 'omega-ruby-alpha-sapphire',
#       'url': 'https://pokeapi.co/api/v2/version-group/16/'}}]}],
#  'name': 'charmander',
#  'order': 5,
#  'past_types': [],
#  'species': {'name': 'charmander',
#   'url': 'https://pokeapi.co/api/v2/pokemon-species/4/'},
#  'sprites': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/4.png',
#   'back_female': None,
#   'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/shiny/4.png',
#   'back_shiny_female': None,
#   'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/4.png',
#   'front_female': None,
#   'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/4.png',
#   'front_shiny_female': None,
#   'other': {'dream_world': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/dream-world/4.svg',
#     'front_female': None},
#    'home': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/4.png',
#     'front_female': None,
#     'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/shiny/4.png',
#     'front_shiny_female': None},
#    'official-artwork': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/4.png'}},
#   'versions': {'generation-i': {'red-blue': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/back/4.png',
#      'back_gray': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/back/gray/4.png',
#      'back_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/transparent/back/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/4.png',
#      'front_gray': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/gray/4.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/red-blue/transparent/4.png'},
#     'yellow': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/back/4.png',
#      'back_gray': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/back/gray/4.png',
#      'back_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/transparent/back/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/4.png',
#      'front_gray': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/gray/4.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-i/yellow/transparent/4.png'}},
#    'generation-ii': {'crystal': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/back/4.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/back/shiny/4.png',
#      'back_shiny_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/transparent/back/shiny/4.png',
#      'back_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/transparent/back/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/4.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/shiny/4.png',
#      'front_shiny_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/transparent/shiny/4.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/crystal/transparent/4.png'},
#     'gold': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/back/4.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/back/shiny/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/4.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/shiny/4.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/gold/transparent/4.png'},
#     'silver': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/back/4.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/back/shiny/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/4.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/shiny/4.png',
#      'front_transparent': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-ii/silver/transparent/4.png'}},
#    'generation-iii': {'emerald': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/emerald/4.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/emerald/shiny/4.png'},
#     'firered-leafgreen': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/firered-leafgreen/back/4.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/firered-leafgreen/back/shiny/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/firered-leafgreen/4.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/firered-leafgreen/shiny/4.png'},
#     'ruby-sapphire': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/ruby-sapphire/back/4.png',
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/ruby-sapphire/back/shiny/4.png',
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/ruby-sapphire/4.png',
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iii/ruby-sapphire/shiny/4.png'}},
#    'generation-iv': {'diamond-pearl': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/back/4.png',
#      'back_female': None,
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/back/shiny/4.png',
#      'back_shiny_female': None,
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/diamond-pearl/shiny/4.png',
#      'front_shiny_female': None},
#     'heartgold-soulsilver': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/back/4.png',
#      'back_female': None,
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/back/shiny/4.png',
#      'back_shiny_female': None,
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/heartgold-soulsilver/shiny/4.png',
#      'front_shiny_female': None},
#     'platinum': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/back/4.png',
#      'back_female': None,
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/back/shiny/4.png',
#      'back_shiny_female': None,
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-iv/platinum/shiny/4.png',
#      'front_shiny_female': None}},
#    'generation-v': {'black-white': {'animated': {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/back/4.gif',
#       'back_female': None,
#       'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/back/shiny/4.gif',
#       'back_shiny_female': None,
#       'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/4.gif',
#       'front_female': None,
#       'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/animated/shiny/4.gif',
#       'front_shiny_female': None},
#      'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/back/4.png',
#      'back_female': None,
#      'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/back/shiny/4.png',
#      'back_shiny_female': None,
#      'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-v/black-white/shiny/4.png',
#      'front_shiny_female': None}},
#    'generation-vi': {'omegaruby-alphasapphire': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/omegaruby-alphasapphire/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/omegaruby-alphasapphire/shiny/4.png',
#      'front_shiny_female': None},
#     'x-y': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/x-y/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vi/x-y/shiny/4.png',
#      'front_shiny_female': None}},
#    'generation-vii': {'icons': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vii/icons/4.png',
#      'front_female': None},
#     'ultra-sun-ultra-moon': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vii/ultra-sun-ultra-moon/4.png',
#      'front_female': None,
#      'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-vii/ultra-sun-ultra-moon/shiny/4.png',
#      'front_shiny_female': None}},
#    'generation-viii': {'icons': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/versions/generation-viii/icons/4.png',
#      'front_female': None}}}},
#  'stats': [{'base_stat': 39,
#    'effort': 0,
#    'stat': {'name': 'hp', 'url': 'https://pokeapi.co/api/v2/stat/1/'}},
#   {'base_stat': 52,
#    'effort': 0,
#    'stat': {'name': 'attack', 'url': 'https://pokeapi.co/api/v2/stat/2/'}},
#   {'base_stat': 43,
#    'effort': 0,
#    'stat': {'name': 'defense', 'url': 'https://pokeapi.co/api/v2/stat/3/'}},
#   {'base_stat': 60,
#    'effort': 0,
#    'stat': {'name': 'special-attack',
#     'url': 'https://pokeapi.co/api/v2/stat/4/'}},
#   {'base_stat': 50,
#    'effort': 0,
#    'stat': {'name': 'special-defense',
#     'url': 'https://pokeapi.co/api/v2/stat/5/'}},
#   {'base_stat': 65,
#    'effort': 1,
#    'stat': {'name': 'speed', 'url': 'https://pokeapi.co/api/v2/stat/6/'}}],
#  'types': [{'slot': 1,
#    'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}],
#  'weight': 85}

# %%
# Let's check out some details about the response
char_json = resp.json()

# %%
char_json.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'past_types', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
# Check the id
char_json['id']
# Out:
# 4

# %%
# Check the name
char_json['name']
# Out:
# 'charmander'

# %%
# Check the types
char_json['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]

# %% [markdown]
# #### Helper Function!
#
# Let's write a function that, given a response from this API's pokemon endpoint, returns a list of the ID, name, primary type _and secondary type_ for that pokemon.
#
# Note that Charmander here just has one type - what would a pokemon with two types look like? Note that Bulbasaur is both grass and poison types.

# %%
# Code here to explore
bulba = base_poke_url + '1/'
bulba
# Out:
# 'https://pokeapi.co/api/v2/pokemon/1/'

# %%
resp = requests.get(bulba)
resp.status_code
# Out:
# 200

# %%
resp.json()['name']
# Out:
# 'bulbasaur'

# %%
# Now - write the function!
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, primary type and secondary type 
    '''
    if len(poke_resp['types'])==1:
        secondary_type = None
    else:
        secondary_type = poke_resp['types'][1]['type']['name']
        
    return [poke_resp['id'],
            poke_resp['name'],         
            poke_resp['types'][0]['type']['name'],
            secondary_type
           ]

# %%
# Let's test our function on the 3 original starter pokemon
original_starter_ids = list(range(1,10, 3))
print(original_starter_ids)
# Out:
# [1, 4, 7]

# %%
# Run this code to check our work
for poke_id in original_starter_ids:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    print(details)
# Out:
# [1, 'bulbasaur', 'grass', 'poison']
# [4, 'charmander', 'fire', None]
# [7, 'squirtle', 'water', None]

# %% [markdown]
# ### Moving to Pandas
#
# Let's get all of these details for all of the original 151 pokemon! And save them to a Pandas dataframe.

# %%
# Need to import panda
import pandas as pd

# %%
# Let's go ahead and define what our columns will be
col_names = ['id', 'name', 'primary_type', 'secondary_type']

# %%
# Define a list of our 151 pokemon ids
original_151 = list(range(1,152))

# %% [markdown]
# So we're going to make 151 requests... don't want to overload the API endpoint! So let's use the `time` library to space out our requests.

# %%
import time

# %%
# Easiest way to do this will be to have a list of lists, then concat them all

# Define a blank list to capture all the pokemon details
row_list = []

# And then loop over our pokemon ids!
# Let's write this together!
for poke_id in original_151:
    url = f'{base_poke_url}{poke_id}/'
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    row_list.append(details)
    time.sleep(.5)
    
# Then, concat everything into one df
poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)

# %%
poke_df.tail()
# Out:
#       id       name primary_type secondary_type
# 146  147    dratini       dragon           None
# 147  148  dragonair       dragon           None
# 148  149  dragonite       dragon         flying
# 149  150     mewtwo      psychic           None
# 150  151        mew      psychic           None

# %%
# visualize it!
import matplotlib.pyplot as plt

primary_type_count = poke_df.groupby('primary_type').count()['id'].sort_values(ascending=False)

plt.figure(figsize=(10,8))
plt.bar(primary_type_count.index, primary_type_count)

plt.title("Counts of Pokemon Primary Types")
plt.ylabel("Number of Pokemon")
plt.xlabel("Primary Type")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ![monty python gif - and now for something completely different, from giphy](https://media.giphy.com/media/xznyPebL28X5u/giphy.gif)

# %% [markdown]
# # Movie Time!
#
# Let's practice with an API that actually requires some authorization, in the form of an API Key!

# %% [markdown]
# # **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call. (There are even more options than that, but these are two easily-accessible ones)

# %%
# Option 1: use a json file saved to some other folder outside your Git repo
# In a new terminal window, create a file called api.json and save the path to that file

# Need to import json to do this
import json

# Define a function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)


# Using the function to open and load all keys in that file 
all_keys = get_keys('../../../.secrets/tmdb.json')

# Setting the first (and only) value as a variable
tmdb_1 = all_keys['tmdb_key']

# %%
# Option 2: use a python file that's been added to your .gitignore

# In a new terminal window, create a file called keys.py in this repo
# Save the api key as tmdb_api_key = "[key]"





# Then let's edit our .gitignore file together

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but **be sure to clear the output of that cell** or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %% [markdown]
# ### And now, accessing movie data
#
# Documentation: https://developers.themoviedb.org/3

# %%
# Default URL given as an example... let's see what it is!
example_url = f'https://api.themoviedb.org/3/movie/550?api_key={tmdb_1}'

# %%
# Get the response

# %%
# Check the keys

# %%
# Find similar movies to the previous id

# %%
# Check out that response

# %%
# How many similar movies did it find?

# %%
# but is that the length of these results?

# %%
# what's in here?

# %% [markdown]
# ## Level Up - Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).

# %% [markdown]
# ## Extra Credit - Further Practice
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
